# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (10, 6)
style.use('seaborn-whitegrid')

# %% [markdown]
# # Task 1

# %%
def sir(x, beta, gamma, n):
    """
    Single run of SIR model.
    Args:
        x - s, i, r values vector,
        beta - infection rate,
        gamma - recovery rate,
        n - population size.
    """
    s, i , r = x
    ds = -beta*s*i / n
    di = beta*s*i / n - gamma*i
    dr = gamma*i
    return np.array([ds, di, dr])

# %%
def euler(x0, beta, gamma, n, steps):
    """
    Euler method for SIR model.
    Args:
        x0 - initial conditions vector,
        beta - infection rate,
        gamma - recovery rate,
        n - population size,
        steps - number of values to compute.
    """
    assert len(x0) == 3
    
    x = np.zeros([steps, 3])
    x[0] = x0

    for i in range(1, steps):
        x[i] = x[i-1] + sir(x[i-1], beta, gamma, n)

    x_df = pd.DataFrame(x)
    x_df.columns = ['S', 'I', 'R']
    
    return x_df

# %%
n = 100
x0 = [n-1, 1, 0]

# %% [markdown]
# ### $R_0 > 1$

# %%
beta1 = 0.4
gamma1 = 0.1
r1 = beta1*n / gamma1
r1
# Out:
# 400.0

# %%
e1 = euler(x0, beta1, gamma1, n, 1000)

# %%
e1.plot(title=r'SIR for $\beta=0.4$, $\gamma=0.1$, $n=100$, $R_0=400$')
plt.xlim([0, 100])
plt.show()

# %% [markdown]
# On the above plot we can see that there was an epidemic outburst.

# %%
beta2 = 0.8
gamma2 = 0.5
r2 = beta2*n / gamma2
r2
# Out:
# 160.0

# %%
e2 = euler(x0, beta2, gamma2, n, 1000)

# %%
e2.plot(title=r'SIR for $\beta=0.8$, $\gamma=0.5$, $n=100$, $R_0=160$')
plt.xlim([0, 100])
plt.show()

# %% [markdown]
# For this set of parameters, we also observe an epidemic outburs, but this time much smaller.

# %%
beta3 = 0.2
gamma3 = 0.4
r3 = beta3*n / gamma3
r3
# Out:
# 50.0

# %%
e3 = euler(x0, beta3, gamma3, n, 1000)

# %%
e3.plot(title=r'SIR for $\beta=0.2$, $\gamma=0.4$, $n=100$, $R_0 = 50$')
plt.xlim([0, 100])
plt.show()

# %% [markdown]
# We see now that as we put $\beta < \gamma$, we observe no epidemic outburst, even though we have $R_0 > 1$. To make sure that's the case, we plot the $I$ component separately.

# %%
e3['I'].plot(title=r'I for $\beta=0.2$, $\gamma=0.4$, $n=100$, $R_0 = 50$', color='orange')
plt.xlim([0, 100])
plt.show()

# %% [markdown]
# We see that, in fact, an infected individual recovered, causing no further infections.

# %% [markdown]
# ### $R_0 < 1$

# %%
beta4 = 0.5
gamma4 = 51
r4 = beta4*n / gamma4
r4
# Out:
# 0.9803921568627451

# %%
e4 = euler(x0, beta4, gamma4, n, 1000)
# Out:
# <ipython-input-3-8c2bc8785d8b>:3: RuntimeWarning: overflow encountered in double_scalars
#   ds = -beta*s*i / n
# <ipython-input-3-8c2bc8785d8b>:4: RuntimeWarning: overflow encountered in double_scalars
#   di = beta*s*i / n - gamma*i
# <ipython-input-3-8c2bc8785d8b>:4: RuntimeWarning: invalid value encountered in double_scalars
#   di = beta*s*i / n - gamma*i

# %%
e4.plot(title=r'SIR for $\beta=0.5$, $\gamma=51$, $n=100$, $R_0 \approx 0.98$')
plt.show()

# %% [markdown]
# Let's look at each component separately.

# %%
e4.plot(title=r'SIR for $\beta=0.5$, $\gamma=51$, $n=100$, $R_0 \approx 0.98$', subplots=True)
plt.show()

# %% [markdown]
# We definitely don't observe an epidemic outburst.

# %%
beta5 = 0.1
gamma5 = 15
r5 = beta5*n / gamma5
r5
# Out:
# 0.6666666666666666

# %%
e5 = euler(x0, beta5, gamma5, n, 1000)
# Out:
# <ipython-input-3-8c2bc8785d8b>:3: RuntimeWarning: overflow encountered in double_scalars
#   ds = -beta*s*i / n
# <ipython-input-3-8c2bc8785d8b>:4: RuntimeWarning: overflow encountered in double_scalars
#   di = beta*s*i / n - gamma*i
# <ipython-input-3-8c2bc8785d8b>:4: RuntimeWarning: invalid value encountered in double_scalars
#   di = beta*s*i / n - gamma*i

# %%
e5.plot(title=r'SIR for $\beta=0.1$, $\gamma=15$, $n=100$, $R_0 \approx 0.66$')
plt.show()

# %%
e5.plot(title=r'SIR for $\beta=0.1$, $\gamma=15$, $n=100$, $R_0 \approx 0.66$', subplots=True)
plt.show()

# %% [markdown]
# Again, obtained plots are very odd and we don't observe an epidemic.

# %%
def si(x, beta, gamma, n):
    """
    Single run of SI model.
    Args:
        x - s, i values vector,
        beta - infection rate,
        gamma - recovery rate,
        n - population size.
    """
    s, i = x
    ds = -beta*s*i / n
    di = beta*s*i / n - gamma*i
    
    return np.array([ds, di])

# %%
s0 = np.linspace(1, 100, 20)
i0 = np.linspace(1, 100, 20)
S, I = np.meshgrid(s0, i0)
u, v = np.zeros(S.shape), np.zeros(I.shape)
n1, n2 = S.shape

# %%
for j in range(n1):
    for k in range(n2):
        s = S[j, k]
        i = I[j, k]
        SI = si([s, i], beta1, gamma1, n+1)
        u[j, k] = SI[0]
        v[j, k] = SI[1]

# %%
style.use('default')
plt.quiver(S, I, u, v, color='blue')
plt.xlim([-10, 110])
plt.ylim([-10, 110])
plt.show()
